# %% [markdown]
# # William Craske

# %% [markdown]
# ## Research question/interests
#
# Finding the likelihood or trend of scoring when on a power play or down a player, compared to whether it's the winning goal.

# %%
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns


nhlStats = pd.read_csv(r"..\data\raw\nhlStats.csv", low_memory = False)
nhlStats = nhlStats.dropna(how="any", axis = 0)
nhlStats
# Out:
#             game_id  player_id  team_id  timeOnIce  assists  goals  pim  \
# 1      2.016020e+09  8473461.0      4.0     2011.0      0.0    0.0  0.0
# 2      2.016020e+09  8470645.0     16.0     3598.0      0.0    0.0  0.0
# 3      2.017021e+09  8468011.0     24.0     3696.0      0.0    0.0  0.0
# 4      2.017021e+09  8475215.0      7.0     3539.0      0.0    0.0  0.0
# 5      2.015020e+09  8473575.0     21.0     3600.0      0.0    0.0  0.0
# ...             ...        ...      ...        ...      ...    ...  ...
# 56649  2.018030e+09  8476412.0     19.0     3487.0      0.0    0.0  0.0
# 56650  2.018030e+09  8471695.0      6.0     3600.0      0.0    0.0  0.0
# 56651  2.018030e+09  8476412.0     19.0     3487.0      0.0    0.0  0.0
# 56652  2.018030e+09  8476412.0     19.0     3600.0      0.0    0.0  0.0
# 56654  2.018030e+09  8476412.0     19.0     3600.0      0.0    0.0  0.0
#
#        shots  saves  powerPlaySaves  ...  evenShotsAgainst  \
# 1       11.0    9.0             1.0  ...              10.0
# 2       27.0   23.0             2.0  ...              23.0
# 3       33.0   30.0             1.0  ...              28.0
# 4       33.0   29.0             4.0  ...              27.0
# 5       21.0   20.0             3.0  ...              17.0
# ...      ...    ...             ...  ...               ...
# 56649   31.0   27.0             3.0  ...              26.0
# 56650   29.0   28.0            12.0  ...              16.0
# 56651   31.0   27.0             3.0  ...              26.0
# 56652   33.0   32.0             3.0  ...              30.0
# 56654   33.0   32.0             3.0  ...              30.0
#
#        powerPlayShotsAgainst  decision  savePercentage  \
# 1                        1.0         L       81.818182
# 2                        4.0         W       85.185185
# 3                        2.0         W       90.909091
# 4                        5.0         L       87.878788
# 5                        3.0         W       95.238095
# ...                      ...       ...             ...
# 56649                    4.0         L       87.096774
# 56650                   12.0         W       96.551724
# 56651                    4.0         L       87.096774
# 56652                    3.0         W       96.969697
# 56654                    3.0         W       96.969697
#
#        powerPlaySavePercentage evenStrengthSavePercentage         play_id  \
# 1                        100.0                  80.000000   2016020045_97
# 2                         50.0                  91.304348  2016020045_103
# 3                         50.0                  96.428571  2016020045_140
# 4                         80.0                  88.888889  2016020045_197
# 5                        100.0                  94.117647  2016020045_214
# ...                        ...                        ...             ...
# 56649                     75.0                  88.461538    2009020965_5
# 56650                    100.0                  93.750000    2009020965_7
# 56651                     75.0                  88.461538   2009020965_10
# 56652                    100.0                  96.666667    2009020751_2
# 56654                    100.0                  96.666667    2009020751_6
#
#          strength  gameWinningGoal emptyNet
# 1            Even            False    False
# 2      Power Play            False    False
# 3      Power Play            False    False
# 4      Power Play            False    False
# 5            Even            False    False
# ...           ...              ...      ...
# 56649  Power Play            False    False
# 56650        Even            False    False
# 56651        Even             True    False
# 56652        Even            False    False
# 56654        Even            False    False
#
# [46935 rows x 23 columns]

# %% [markdown]
# # Milestone 3

# %%
nhlStats.head()
# Out:
#         game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 1  2.016020e+09  8473461.0      4.0     2011.0      0.0    0.0  0.0   11.0
# 2  2.016020e+09  8470645.0     16.0     3598.0      0.0    0.0  0.0   27.0
# 3  2.017021e+09  8468011.0     24.0     3696.0      0.0    0.0  0.0   33.0
# 4  2.017021e+09  8475215.0      7.0     3539.0      0.0    0.0  0.0   33.0
# 5  2.015020e+09  8473575.0     21.0     3600.0      0.0    0.0  0.0   21.0
#
#    saves  powerPlaySaves  ...  evenShotsAgainst  powerPlayShotsAgainst  \
# 1    9.0             1.0  ...              10.0                    1.0
# 2   23.0             2.0  ...              23.0                    4.0
# 3   30.0             1.0  ...              28.0                    2.0
# 4   29.0             4.0  ...              27.0                    5.0
# 5   20.0             3.0  ...              17.0                    3.0
#
#    decision  savePercentage  powerPlaySavePercentage  \
# 1         L       81.818182                    100.0
# 2         W       85.185185                     50.0
# 3         W       90.909091                     50.0
# 4         L       87.878788                     80.0
# 5         W       95.238095                    100.0
#
#   evenStrengthSavePercentage         play_id    strength  gameWinningGoal  \
# 1                  80.000000   2016020045_97        Even            False
# 2                  91.304348  2016020045_103  Power Play            False
# 3                  96.428571  2016020045_140  Power Play            False
# 4                  88.888889  2016020045_197  Power Play            False
# 5                  94.117647  2016020045_214        Even            False
#
#   emptyNet
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
#
# [5 rows x 23 columns]

# %%
nhlStats.shape
# Out:
# (46935, 23)

# %%
nhlStats.columns
# Out:
# Index(['game_id', 'player_id', 'team_id', 'timeOnIce', 'assists', 'goals',
#        'pim', 'shots', 'saves', 'powerPlaySaves', 'shortHandedSaves',
#        'evenSaves', 'shortHandedShotsAgainst', 'evenShotsAgainst',
#        'powerPlayShotsAgainst', 'decision', 'savePercentage',
#        'powerPlaySavePercentage', 'evenStrengthSavePercentage', 'play_id',
#        'strength', 'gameWinningGoal', 'emptyNet'],
#       dtype='object')

# %%
nhlStats.nunique(axis=0)
nhlStats.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#                   gameID     timeOnIce       assists         goals  \
# count       46935.000000  46935.000000  46935.000000  46935.000000
# mean   2010693177.759412   3539.906594      0.022094      0.000192
# std       6061441.176228    431.962762      0.148578      0.013846
# min    2000020001.000000    196.000000      0.000000      0.000000
# 25%    2006020350.000000   3550.000000      0.000000      0.000000
# 50%    2011020585.000000   3600.000000      0.000000      0.000000
# 75%    2016021095.000000   3600.000000      0.000000      0.000000
# max    2019030416.000000   9027.000000      2.000000      1.000000
#
#         penaltyMins         shots         saves powerPlaySaves  \
# count  46935.000000  46935.000000  46935.000000   46935.000000
# mean       0.090785     29.346096     26.775498       4.549142
# std        0.593859      7.378900      7.378235       3.096832
# min        0.000000      2.000000      1.000000       0.000000
# 25%        0.000000     25.000000     22.000000       2.000000
# 50%        0.000000     29.000000     27.000000       4.000000
# 75%        0.000000     34.000000     31.000000       6.000000
# max       27.000000     88.000000     85.000000      25.000000
#
#       shortHandedSaves     evenSaves shortHandShotsAgainst evenShotsAgainst  \
# count     46935.000000  46935.000000          46935.000000     46935.000000
# mean          0.825972     21.399787              0.902141        23.219708
# std           1.069898      6.684599              1.128939         6.776589
# min          -1.000000      0.000000              0.000000         1.000000
# 25%           0.000000     17.000000              0.000000        19.000000
# 50%           1.000000     21.000000              1.000000        23.000000
# 75%           1.000000     26.000000              1.000000        28.000000
# max          15.000000     76.000000             15.000000        79.000000
#
#       powerPlayShotsAgainst savePercentage powerPlaySavePercentage  \
# count          46935.000000   46935.000000            46935.000000
# mean               5.223479      90.666790               84.663853
# std                3.277791       6.269778               22.013991
# min                1.000000      20.000000                0.000000
# 25%                3.000000      87.500000               75.000000
# 50%                5.000000      91.666667               92.857143
# 75%                7.000000      95.000000              100.000000
# max               28.000000     100.000000              100.000000
#
#       evenStrengthSavePercentage
# count               46935.000000
# mean                   91.621785
# std                     6.742545
# min                     0.000000
# 25%                    88.235294
# 50%                    92.592593
# 75%                    96.000000
# max                   100.000000

# %%
nhlStats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46935 entries, 46932 to 1
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gameID                      46935 non-null  float64
#  1   timeOnIce                   46935 non-null  float64
#  2   assists                     46935 non-null  float64
#  3   goals                       46935 non-null  float64
#  4   penaltyMins                 46935 non-null  float64
#  5   shots                       46935 non-null  float64
#  6   saves                       46935 non-null  float64
#  7   powerPlaySaves              46935 non-null  float64
#  8   shortHandedSaves            46935 non-null  float64
#  9   evenSaves                   46935 non-null  float64
#  10  shortHandShotsAgainst       46935 non-null  float64
#  11  evenShotsAgainst            46935 non-null  float64
#  12  powerPlayShotsAgainst       46935 non-null  float64
#  13  result                      46935 non-null  object
#  14  savePercentage              46935 non-null  float64
#  15  powerPlaySavePercentage     46935 non-null  float64
#  16  evenStrengthSavePercentage  46935 non-null  float64
#  17  playID                      46935 non-null  object
#  18  strength                    46935 non-null  object
#  19  gameWinningGoal             46935 non-null  object
#  20  emptyNet                    46935 non-null  object
# dtypes: float64(16), object(5)
# memory usage: 7.9+ MB

# %%
nhlStats.isnull().sum()
# Out:
# gameID                        0
# timeOnIce                     0
# assists                       0
# goals                         0
# penaltyMins                   0
# shots                         0
# saves                         0
# powerPlaySaves                0
# shortHandedSaves              0
# evenSaves                     0
# shortHandShotsAgainst         0
# evenShotsAgainst              0
# powerPlayShotsAgainst         0
# result                        0
# savePercentage                0
# powerPlaySavePercentage       0
# evenStrengthSavePercentage    0
# playID                        0
# strength                      0
# gameWinningGoal               0
# emptyNet                      0
# dtype: int64

# %%
nhlStats = pd.read_csv(r"..\data\raw\nhlStats.csv", low_memory = False)

nhlStats = nhlStats.dropna(how="any", axis = 0)

nhlStats = nhlStats.rename(columns = {"game_id" : "gameID", "player_id" : "playerID",
                                      "team_id" : "teamID", "pim" : "penaltyMins",
                                      "shortHandedShotsAgainst" : "shortHandShotsAgainst",
                                      "play_id" : "playID", "decision" : "result"})


nhlStats = nhlStats[['gameID','gameWinningGoal',
       'powerPlayShotsAgainst','goals','timeOnIce', 'assists',
       'penaltyMins', 'shots', 'saves', 'powerPlaySaves', 'shortHandedSaves',
       'evenSaves', 'shortHandShotsAgainst', 'evenShotsAgainst', 'result', 'savePercentage',
       'powerPlaySavePercentage', 'evenStrengthSavePercentage', 'playID',
       'strength','emptyNet']]

nhlStats = nhlStats.sort_values(by=["gameID"], ascending = False)

nhlStats
# Out:
#              gameID gameWinningGoal  powerPlayShotsAgainst  goals  timeOnIce  \
# 50837  2.019030e+09            True                    3.0    0.0     3493.0
# 50836  2.019030e+09           False                    3.0    0.0     3600.0
# 50835  2.019030e+09           False                    3.0    0.0     3493.0
# 50834  2.019030e+09           False                    3.0    0.0     3600.0
# 50832  2.019030e+09           False                    3.0    0.0     5350.0
# ...             ...             ...                    ...    ...        ...
# 38957  2.000020e+09           False                    8.0    0.0     3600.0
# 41309  2.000020e+09           False                   15.0    0.0     3900.0
# 41310  2.000020e+09            True                    5.0    0.0     3900.0
# 39728  2.000020e+09           False                   10.0    0.0     3900.0
# 39727  2.000020e+09           False                   10.0    0.0     3880.0
#
#        assists  penaltyMins  shots  saves  powerPlaySaves  ...  evenSaves  \
# 50837      0.0          0.0   29.0   27.0             2.0  ...       23.0
# 50836      0.0          0.0   22.0   22.0             3.0  ...       19.0
# 50835      0.0          0.0   29.0   27.0             2.0  ...       23.0
# 50834      0.0          0.0   22.0   22.0             3.0  ...       19.0
# 50832      0.0          0.0   41.0   39.0             3.0  ...       36.0
# ...        ...          ...    ...    ...             ...  ...        ...
# 38957      0.0          0.0   30.0   26.0             8.0  ...       17.0
# 41309      0.0          0.0   38.0   34.0            13.0  ...       19.0
# 41310      0.0          0.0   33.0   29.0             3.0  ...       23.0
# 39728      0.0          0.0   28.0   26.0             9.0  ...       17.0
# 39727      0.0          0.0   21.0   19.0             9.0  ...       10.0
#
#        shortHandShotsAgainst  evenShotsAgainst  result savePercentage  \
# 50837                    2.0              24.0       L      93.103448
# 50836                    0.0              19.0       W     100.000000
# 50835                    2.0              24.0       L      93.103448
# 50834                    0.0              19.0       W     100.000000
# 50832                    0.0              38.0       W      95.121951
# ...                      ...               ...     ...            ...
# 38957                    1.0              21.0       L      86.666667
# 41309                    2.0              21.0       L      89.473684
# 41310                    3.0              25.0       W      87.878788
# 39728                    0.0              18.0       L      92.857143
# 39727                    0.0              11.0       W      90.476190
#
#        powerPlaySavePercentage  evenStrengthSavePercentage          playID  \
# 50837                66.666667                   95.833333  2011020546_169
# 50836               100.000000                  100.000000  2011020546_163
# 50835                66.666667                   95.833333  2011020546_143
# 50834               100.000000                  100.000000  2011020546_141
# 50832               100.000000                   94.736842    2011020546_8
# ...                        ...                         ...             ...
# 38957               100.000000                   80.952381  2010020921_301
# 41309                86.666667                   90.476190  2010020619_176
# 41310                60.000000                   92.000000  2010020619_320
# 39728                90.000000                   94.444444  2011020808_123
# 39727                90.000000                   90.909091  2011020496_271
#
#       strength emptyNet
# 50837     Even    False
# 50836     Even    False
# 50835     Even    False
# 50834     Even    False
# 50832     Even    False
# ...        ...      ...
# 38957     Even    False
# 41309     Even    False
# 41310     Even    False
# 39728     Even    False
# 39727     Even    False
#
# [46935 rows x 21 columns]

# %%
def loadAndProcess(address):
    
    #method chain 1 - load data, deal with missing data
    df1 = (
        pd.read_csv(address, low_memory = False)
        .dropna(how="any", axis = 0)
        
    )
    
    #method chain 2 - rename columns, and sort by gameID
    df2 = (
        df1
        .rename(columns = {"game_id" : "gameID", "player_id" : "playerID",
                                      "team_id" : "teamID", "pim" : "penaltyMins",
                                      "shortHandedShotsAgainst" : "shortHandShotsAgainst",
                                      "play_id" : "playID", "decision" : "result"})
        .sort_values(by=["gameID"], ascending = False)
        
    )
    return df2

loadAndProcess(r"..\data\raw\nhlStats.csv")
# Out:
#              gameID   playerID  teamID  timeOnIce  assists  goals  \
# 50837  2.019030e+09  8471418.0    25.0     3493.0      0.0    0.0
# 50836  2.019030e+09  8476883.0    14.0     3600.0      0.0    0.0
# 50835  2.019030e+09  8471418.0    25.0     3493.0      0.0    0.0
# 50834  2.019030e+09  8476883.0    14.0     3600.0      0.0    0.0
# 50832  2.019030e+09  8471418.0    25.0     5350.0      0.0    0.0
# ...             ...        ...     ...        ...      ...    ...
# 38957  2.000020e+09  8459432.0    16.0     3600.0      0.0    0.0
# 41309  2.000020e+09  8459579.0     9.0     3900.0      0.0    0.0
# 41310  2.000020e+09  8455994.0     6.0     3900.0      0.0    0.0
# 39728  2.000020e+09  8445386.0    25.0     3900.0      0.0    0.0
# 39727  2.000020e+09  8451033.0    21.0     3880.0      0.0    0.0
#
#        penaltyMins  shots  saves  powerPlaySaves  ...  evenShotsAgainst  \
# 50837          0.0   29.0   27.0             2.0  ...              24.0
# 50836          0.0   22.0   22.0             3.0  ...              19.0
# 50835          0.0   29.0   27.0             2.0  ...              24.0
# 50834          0.0   22.0   22.0             3.0  ...              19.0
# 50832          0.0   41.0   39.0             3.0  ...              38.0
# ...            ...    ...    ...             ...  ...               ...
# 38957          0.0   30.0   26.0             8.0  ...              21.0
# 41309          0.0   38.0   34.0            13.0  ...              21.0
# 41310          0.0   33.0   29.0             3.0  ...              25.0
# 39728          0.0   28.0   26.0             9.0  ...              18.0
# 39727          0.0   21.0   19.0             9.0  ...              11.0
#
#        powerPlayShotsAgainst  result  savePercentage  powerPlaySavePercentage  \
# 50837                    3.0       L       93.103448                66.666667
# 50836                    3.0       W      100.000000               100.000000
# 50835                    3.0       L       93.103448                66.666667
# 50834                    3.0       W      100.000000               100.000000
# 50832                    3.0       W       95.121951               100.000000
# ...                      ...     ...             ...                      ...
# 38957                    8.0       L       86.666667               100.000000
# 41309                   15.0       L       89.473684                86.666667
# 41310                    5.0       W       87.878788                60.000000
# 39728                   10.0       L       92.857143                90.000000
# 39727                   10.0       W       90.476190                90.000000
#
#       evenStrengthSavePercentage          playID  strength  gameWinningGoal  \
# 50837                  95.833333  2011020546_169      Even             True
# 50836                 100.000000  2011020546_163      Even            False
# 50835                  95.833333  2011020546_143      Even            False
# 50834                 100.000000  2011020546_141      Even            False
# 50832                  94.736842    2011020546_8      Even            False
# ...                          ...             ...       ...              ...
# 38957                  80.952381  2010020921_301      Even            False
# 41309                  90.476190  2010020619_176      Even            False
# 41310                  92.000000  2010020619_320      Even             True
# 39728                  94.444444  2011020808_123      Even            False
# 39727                  90.909091  2011020496_271      Even            False
#
#       emptyNet
# 50837    False
# 50836    False
# 50835    False
# 50834    False
# 50832    False
# ...        ...
# 38957    False
# 41309    False
# 41310    False
# 39728    False
# 39727    False
#
# [46935 rows x 23 columns]
